# %%
import tensorflow as tf
import json
import numpy as np
import pandas as pd

from google.cloud import bigquery
from google.cloud import storage

from google.cloud import aiplatform


import matplotlib.pyplot as plt
import seaborn as sns
#https://github.com/GoogleCloudPlatform/vertex-ai-samples/blob/main/notebooks/official/custom/custom-tabular-bq-managed-dataset.ipynb

# %%
print(tf.__version__)
# Out:
# 2.11.0

# %%
#table_id='new_incident'
table_id='test_incident'
# table_id='validation_incident'

projectId='pongthorn'
dataset_id='DemoSMartDW'
REGION="asia-southeast1"

if  table_id=='new_incident':
 unUsedColtoPredict=['severity','id','severity_id','severity_name','imported_at']
 filePath='../../data/Bi_Prediction_New_Incident.csv'
elif table_id=='test_incident' or table_id=='validation_incident':
 unUsedColtoPredict=['severity','id','severity_id','severity_name']  
 filePath=f'../../data/Bi_Prediction_{table_id}.csv'
    
isLocalModel=True

isBQToCSV=True

PATH_FOLDER_ARTIFACTS="model_binary"  

modelFile_endPoint=1 
#1=local(dev)/gcs(clound function) and 2=vertext

localFile=True

# %%
# from google.oauth2 import service_account
# mycredentials = service_account.Credentials.from_service_account_file(r'C:\Windows\smart-data-ml-91b6f6204773.json')

if isBQToCSV:
    
    bqclient= bigquery.Client(project=projectId)
    # bqclient= bigquery.Client(project=projectId,credentials=mycredentials)
    def download_table(bq_table_uri: str):

        prefix = "bq://"
        if bq_table_uri.startswith(prefix):
            bq_table_uri = bq_table_uri[len(prefix) :]

        table = bigquery.TableReference.from_string(bq_table_uri)
        rows = bqclient.list_rows(table)
        return rows.to_dataframe()

    dfNewData=download_table(f"{projectId}.{dataset_id}.{table_id}")
    dfNewData.to_csv(filePath,index=False)    
    print(dfNewData.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   severity_id                227 non-null    Int64
#  1   severity_name              227 non-null    object
#  2   sla                        227 non-null    object
#  3   product_type               227 non-null    object
#  4   brand                      227 non-null    object
#  5   service_type               227 non-null    object
#  6   incident_type              227 non-null    object
#  7   open_to_close_hour         227 non-null    float64
#  8   response_to_resolved_hour  227 non-null    float64
#  9   label_multi_severity       227 non-null    Int64
#  10  label_binary_severity      227 non-null    Int64
# dtypes: Int64(3), float64(2), object(6)
# memory usage: 20.3+ KB
# None

# %% [markdown]
# # Load and Map Data Test

# %%
if  localFile:
    dfNewData=pd.read_csv(filePath)

# dfNewData=dfNewData.sample(3)

# %%
mapping_file="incident_sevirity_to_binary.json"

with open(mapping_file, 'r') as json_file:
 map_sevirity_to_class= json.load(json_file)
                                  
print(map_sevirity_to_class)
# Out:
# {'Normal': 0, 'Critical': 1}

# %%
if table_id=='new_incident':
    dfNewData.insert(2, 'severity', dfNewData['severity_name'].map(map_sevirity_to_class),True)
    print(dfNewData.info())
elif table_id=='test_incident' or table_id=='validation_incident':
    
    dfNewData=dfNewData.rename(columns={'label_binary_severity':'severity'})
    dfNewData=dfNewData.drop(columns=['label_multi_severity'])
    if 'id' not in dfNewData.columns.to_list():
        dfNewData=dfNewData.reset_index(drop=True)
        dfNewData = dfNewData.reset_index(level=0)
        dfNewData.rename(columns={"index": "id"},inplace=True)
        dfNewData['id']=dfNewData['id']+1
print(filePath)  

# dfNewData=dfNewData.sample(10)
print(dfNewData.info())
dfNewData.tail(10)
# Out:
# ../../data/Bi_Prediction_test_incident.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         227 non-null    int64
#  1   severity_id                227 non-null    int64
#  2   severity_name              227 non-null    object
#  3   sla                        227 non-null    object
#  4   product_type               227 non-null    object
#  5   brand                      227 non-null    object
#  6   service_type               227 non-null    object
#  7   incident_type              227 non-null    object
#  8   open_to_close_hour         227 non-null    float64
#  9   response_to_resolved_hour  227 non-null    float64
#  10  severity                   227 non-null    int64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 19.6+ KB
# None
#       id  severity_id severity_name                        sla  product_type  \
# 217  218            4      Cosmatic  24x7 4Hrs Resolution Time      Software
# 218  219            4      Cosmatic    24x7 4Hrs Response Time      Software
# 219  220            4      Cosmatic    24x7 4Hrs Response Time      Software
# 220  221            4      Cosmatic  24x7 6Hrs Resolution Time      Software
# 221  222            2         Major  24x7 4Hrs Resolution Time  Access Point
# 222  223            3         Minor  24x7 4Hrs Resolution Time  Access Point
# 223  224            4      Cosmatic  24x7 4Hrs Resolution Time  Access Point
# 224  225            4      Cosmatic     8x5 4Hrs Response Time  Access Point
# 225  226            4      Cosmatic     8x5 4Hrs Response Time  Access Point
# 226  227            2         Major     8x5 4Hrs Response Time  Tape Library
#
#       brand service_type            incident_type  open_to_close_hour  \
# 217  VMWare      Request       Maintenance System           39.000000
# 218  VMWare      Request         General Incident            7.350000
# 219  VMWare      Request         General Incident            8.600000
# 220     YIP      Request         General Incident         1307.216667
# 221   Cisco     Incident         General Incident            1.000000
# 222   Cisco     Incident            Other Failure            4.000000
# 223   Cisco      Request         General Incident            1.500000
# 224     HPE      Request         General Incident            1.000000
# 225     HPE      Request         General Incident            1.000000
# 226     HPE     Incident  Controller/Node Failure           12.383333
#
#      response_to_resolved_hour  severity
# 217                      39.00         0
# 218                       7.35         0
# 219                       8.00         0
# 220                    1303.00         0
# 221                       1.00         1
# 222                       4.00         0
# 223                       1.50         0
# 224                       0.50         0
# 225                       0.50         0
# 226                      12.15         1

# %%
def plot_class(df):
    fig , ax = plt.subplots(figsize=(8,5))
    ax =sns.countplot(x='severity', data=df,)
    for p in ax.patches:
       ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
    plt.title('Severity')
    plt.show()
    
plot_class(dfNewData)

# %% [markdown]
# # Load Model from Directory to Predict

# %%
model = tf.keras.models.load_model(PATH_FOLDER_ARTIFACTS)    
print(f"Load from {PATH_FOLDER_ARTIFACTS}")
# model.summary()
# Out:
# Load from model_binary

# %%
pdPrediction=pd.DataFrame(columns=['_id','_predict_severity'])

for  row_dict in dfNewData.to_dict(orient="records"):
      incident_id=row_dict['id']
      print(f"{incident_id} - {row_dict['severity']}") 
      for key_removed in unUsedColtoPredict:
       row_dict.pop(key_removed)
      # print(row_dict)  

      input_dict = {name: tf.convert_to_tensor([value]) for name, value in row_dict.items()}
      predictionResult = model.predict(input_dict)

      prob = tf.nn.sigmoid(predictionResult[0])
      prob_pct=(100 * prob)   
      _class= 1 if prob[0]>=0.5 else 0  
      print(f"{prob_pct[0]} % at {_class} as 0(Normal)/1(Critcal)") # np.argmax(prob, axis=0
      
      
      pdPrediction =pd.concat([pdPrediction,pd.DataFrame.from_dict([{'_id':incident_id, '_predict_severity':_class}])] )
      # print(input_dict)  
   
      print("======================================================================================")

dfPredictData=pd.merge(dfNewData,pdPrediction,how='inner',left_on='id',right_on='_id')
dfPredictData=dfPredictData.drop(columns=['_id'])
dfPredictData=dfPredictData[['id','_predict_severity','severity']]
dfPredictData
# Out:
# 1 - 1
# 1/1 [==============================] - 1s 692ms/step
# 59.97629928588867 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 2 - 1
# 1/1 [==============================] - 0s 100ms/step
# 59.58858871459961 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 3 - 0
# 1/1 [==============================] - 0s 90ms/step
# 91.37776184082031 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 4 - 0
# 1/1 [==============================] - 0s 110ms/step
# 3.235776662826538 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 5 - 1
# 1/1 [==============================] - 0s 74ms/step
# 80.61275482177734 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 6 - 1
# 1/1 [==============================] - 0s 57ms/step
# 80.6537094116211 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 7 - 1
# 1/1 [==============================] - 0s 72ms/step
# 94.924072265625 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 8 - 1
# 1/1 [==============================] - 0s 66ms/step
# 80.61449432373047 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 9 - 1
# 1/1 [==============================] - 0s 81ms/step
# 80.62523651123047 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 10 - 1
# 1/1 [==============================] - 0s 77ms/step
# 93.31509399414062 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 11 - 1
# 1/1 [==============================] - 0s 69ms/step
# 92.71131896972656 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 12 - 1
# 1/1 [==============================] - 0s 75ms/step
# 94.77767944335938 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 13 - 1
# 1/1 [==============================] - 0s 72ms/step
# 87.54167938232422 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 14 - 1
# 1/1 [==============================] - 0s 62ms/step
# 93.33486938476562 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 15 - 1
# 1/1 [==============================] - 0s 79ms/step
# 39.23337936401367 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 16 - 1
# 1/1 [==============================] - 0s 66ms/step
# 39.37693405151367 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 17 - 1
# 1/1 [==============================] - 0s 83ms/step
# 94.754638671875 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 18 - 1
# 1/1 [==============================] - 0s 79ms/step
# 80.6202621459961 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 19 - 1
# 1/1 [==============================] - 0s 86ms/step
# 39.37693405151367 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 20 - 1
# 1/1 [==============================] - 0s 107ms/step
# 94.25508117675781 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 21 - 1
# 1/1 [==============================] - 0s 85ms/step
# 94.70767211914062 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 22 - 1
# 1/1 [==============================] - 0s 68ms/step
# 94.740966796875 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 23 - 1
# 1/1 [==============================] - 0s 74ms/step
# 94.72660064697266 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 24 - 1
# 1/1 [==============================] - 0s 68ms/step
# 90.66793060302734 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 25 - 1
# 1/1 [==============================] - 0s 52ms/step
# 99.24457550048828 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 26 - 1
# 1/1 [==============================] - 0s 73ms/step
# 43.1607780456543 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 27 - 1
# 1/1 [==============================] - 0s 69ms/step
# 98.61548614501953 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 28 - 1
# 1/1 [==============================] - 0s 73ms/step
# 86.80206298828125 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 29 - 1
# 1/1 [==============================] - 0s 84ms/step
# 93.56351470947266 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 30 - 1
# 1/1 [==============================] - 0s 78ms/step
# 87.52918243408203 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 31 - 1
# 1/1 [==============================] - 0s 68ms/step
# 94.71826171875 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 32 - 1
# 1/1 [==============================] - 0s 54ms/step
# 98.58599853515625 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 33 - 1
# 1/1 [==============================] - 0s 72ms/step
# 94.72103881835938 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 34 - 1
# 1/1 [==============================] - 0s 70ms/step
# 94.765625 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 35 - 1
# 1/1 [==============================] - 0s 59ms/step
# 80.74404907226562 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 36 - 1
# 1/1 [==============================] - 0s 83ms/step
# 94.76504516601562 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 37 - 1
# 1/1 [==============================] - 0s 70ms/step
# 94.68196868896484 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 38 - 1
# 1/1 [==============================] - 0s 80ms/step
# 87.5761947631836 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 39 - 1
# 1/1 [==============================] - 0s 118ms/step
# 94.72096252441406 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 40 - 1
# 1/1 [==============================] - 0s 88ms/step
# 80.6210708618164 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 41 - 1
# 1/1 [==============================] - 0s 89ms/step
# 94.71990966796875 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 42 - 1
# 1/1 [==============================] - 0s 81ms/step
# 87.04352569580078 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 43 - 1
# 1/1 [==============================] - 0s 65ms/step
# 9.7061185836792 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 44 - 1
# 1/1 [==============================] - 0s 73ms/step
# 94.04052734375 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 45 - 1
# 1/1 [==============================] - 0s 60ms/step
# 87.58654022216797 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 46 - 1
# 1/1 [==============================] - 0s 77ms/step
# 94.73101806640625 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 47 - 1
# 1/1 [==============================] - 0s 65ms/step
# 59.622318267822266 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 48 - 1
# 1/1 [==============================] - 0s 89ms/step
# 94.68965911865234 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 49 - 1
# 1/1 [==============================] - 0s 60ms/step
# 82.82971954345703 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 50 - 1
# 1/1 [==============================] - 0s 69ms/step
# 94.70665740966797 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 51 - 1
# 1/1 [==============================] - 0s 56ms/step
# 95.01927947998047 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 52 - 1
# 1/1 [==============================] - 0s 78ms/step
# 97.5506591796875 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 53 - 1
# 1/1 [==============================] - 0s 62ms/step
# 97.18256378173828 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 54 - 0
# 1/1 [==============================] - 0s 78ms/step
# 80.68633270263672 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 55 - 0
# 1/1 [==============================] - 0s 57ms/step
# 53.29857635498047 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 56 - 0
# 1/1 [==============================] - 0s 70ms/step
# 39.446754455566406 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 57 - 0
# 1/1 [==============================] - 0s 62ms/step
# 90.27715301513672 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 58 - 0
# 1/1 [==============================] - 0s 60ms/step
# 94.69593048095703 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 59 - 0
# 1/1 [==============================] - 0s 75ms/step
# 87.5416488647461 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 60 - 0
# 1/1 [==============================] - 0s 73ms/step
# 90.71034240722656 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 61 - 0
# 1/1 [==============================] - 0s 71ms/step
# 0.9117624759674072 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 62 - 0
# 1/1 [==============================] - 0s 77ms/step
# 3.3024537563323975 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 63 - 0
# 1/1 [==============================] - 0s 81ms/step
# 0.9117624759674072 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 64 - 0
# 1/1 [==============================] - 0s 86ms/step
# 39.55486297607422 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 65 - 0
# 1/1 [==============================] - 0s 63ms/step
# 39.41010665893555 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 66 - 0
# 1/1 [==============================] - 0s 68ms/step
# 39.122013092041016 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 67 - 1
# 1/1 [==============================] - 0s 80ms/step
# 51.69779586791992 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 68 - 1
# 1/1 [==============================] - 0s 73ms/step
# 80.72608184814453 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 69 - 1
# 1/1 [==============================] - 0s 71ms/step
# 51.69779586791992 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 70 - 1
# 1/1 [==============================] - 0s 129ms/step
# 51.69779586791992 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 71 - 0
# 1/1 [==============================] - 0s 95ms/step
# 2.115304470062256 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 72 - 0
# 1/1 [==============================] - 0s 92ms/step
# 64.01477813720703 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 73 - 1
# 1/1 [==============================] - 0s 110ms/step
# 91.30583190917969 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 74 - 1
# 1/1 [==============================] - 0s 109ms/step
# 27.37010955810547 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 75 - 1
# 1/1 [==============================] - 0s 106ms/step
# 81.24595642089844 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 76 - 1
# 1/1 [==============================] - 0s 101ms/step
# 88.0368423461914 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 77 - 1
# 1/1 [==============================] - 0s 99ms/step
# 82.42622375488281 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 78 - 1
# 1/1 [==============================] - 0s 110ms/step
# 47.623619079589844 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 79 - 1
# 1/1 [==============================] - 0s 108ms/step
# 91.31558227539062 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 80 - 1
# 1/1 [==============================] - 0s 125ms/step
# 48.8578987121582 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 81 - 1
# 1/1 [==============================] - 0s 141ms/step
# 61.658103942871094 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 82 - 1
# 1/1 [==============================] - 0s 137ms/step
# 33.39693832397461 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 83 - 1
# 1/1 [==============================] - 0s 111ms/step
# 80.9349365234375 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 84 - 1
# 1/1 [==============================] - 0s 144ms/step
# 78.18144226074219 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 85 - 1
# 1/1 [==============================] - 0s 114ms/step
# 15.224141120910645 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 86 - 1
# 1/1 [==============================] - 0s 115ms/step
# 33.2158088684082 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 87 - 1
# 1/1 [==============================] - 0s 132ms/step
# 24.506019592285156 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 88 - 1
# 1/1 [==============================] - 0s 126ms/step
# 81.20796203613281 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 89 - 1
# 1/1 [==============================] - 0s 113ms/step
# 95.1083984375 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 90 - 1
# 1/1 [==============================] - 0s 102ms/step
# 91.34942626953125 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 91 - 1
# 1/1 [==============================] - 0s 102ms/step
# 71.49143981933594 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 92 - 1
# 1/1 [==============================] - 0s 95ms/step
# 72.52472686767578 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 93 - 1
# 1/1 [==============================] - 0s 94ms/step
# 71.45565795898438 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 94 - 0
# 1/1 [==============================] - 0s 104ms/step
# 33.5849609375 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 95 - 0
# 1/1 [==============================] - 0s 86ms/step
# 0.054181892424821854 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 96 - 0
# 1/1 [==============================] - 0s 88ms/step
# 12.5032377243042 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 97 - 0
# 1/1 [==============================] - 0s 86ms/step
# 48.75918197631836 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 98 - 0
# 1/1 [==============================] - 0s 98ms/step
# 63.75935745239258 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 99 - 0
# 1/1 [==============================] - 0s 78ms/step
# 0.18354222178459167 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 100 - 0
# 1/1 [==============================] - 0s 92ms/step
# 33.84416580200195 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 101 - 0
# 1/1 [==============================] - 0s 89ms/step
# 29.683130264282227 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 102 - 0
# 1/1 [==============================] - 0s 94ms/step
# 39.2935905456543 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 103 - 0
# 1/1 [==============================] - 0s 92ms/step
# 46.412086486816406 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 104 - 0
# 1/1 [==============================] - 0s 78ms/step
# 12.695262908935547 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 105 - 0
# 1/1 [==============================] - 0s 85ms/step
# 21.02416229248047 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 106 - 0
# 1/1 [==============================] - 0s 82ms/step
# 46.388214111328125 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 107 - 0
# 1/1 [==============================] - 0s 89ms/step
# 59.22181701660156 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 108 - 0
# 1/1 [==============================] - 0s 87ms/step
# 0.4954777657985687 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 109 - 0
# 1/1 [==============================] - 0s 90ms/step
# 80.5040512084961 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 110 - 0
# 1/1 [==============================] - 0s 94ms/step
# 48.101173400878906 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 111 - 0
# 1/1 [==============================] - 0s 106ms/step
# 47.17818069458008 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 112 - 0
# 1/1 [==============================] - 0s 99ms/step
# 0.5637480020523071 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 113 - 0
# 1/1 [==============================] - 0s 86ms/step
# 0.0671752318739891 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 114 - 0
# 1/1 [==============================] - 0s 90ms/step
# 27.744766235351562 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 115 - 0
# 1/1 [==============================] - 0s 84ms/step
# 0.39385563135147095 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 116 - 0
# 1/1 [==============================] - 0s 65ms/step
# 12.810969352722168 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 117 - 0
# 1/1 [==============================] - 0s 66ms/step
# 82.24783325195312 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 118 - 0
# 1/1 [==============================] - 0s 69ms/step
# 0.4577428102493286 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 119 - 0
# 1/1 [==============================] - 0s 71ms/step
# 0.13983039557933807 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 120 - 0
# 1/1 [==============================] - 0s 81ms/step
# 80.00086212158203 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 121 - 0
# 1/1 [==============================] - 0s 102ms/step
# 24.14973258972168 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 122 - 0
# 1/1 [==============================] - 0s 86ms/step
# 10.716826438903809 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 123 - 0
# 1/1 [==============================] - 0s 76ms/step
# 30.016855239868164 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 124 - 0
# 1/1 [==============================] - 0s 92ms/step
# 60.53915786743164 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 125 - 0
# 1/1 [==============================] - 0s 67ms/step
# 0.31138625741004944 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 126 - 0
# 1/1 [==============================] - 0s 80ms/step
# 1.0844699144363403 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 127 - 0
# 1/1 [==============================] - 0s 77ms/step
# 1.9590179920196533 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 128 - 0
# 1/1 [==============================] - 0s 68ms/step
# 89.57283782958984 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 129 - 0
# 1/1 [==============================] - 0s 84ms/step
# 0.4352898895740509 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 130 - 0
# 1/1 [==============================] - 0s 67ms/step
# 3.049818277359009 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 131 - 0
# 1/1 [==============================] - 0s 81ms/step
# 0.5210356116294861 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 132 - 0
# 1/1 [==============================] - 0s 84ms/step
# 1.0505460500717163 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 133 - 0
# 1/1 [==============================] - 0s 84ms/step
# 0.11319892108440399 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 134 - 1
# 1/1 [==============================] - 0s 80ms/step
# 90.23648071289062 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 135 - 1
# 1/1 [==============================] - 0s 88ms/step
# 92.69857788085938 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 136 - 1
# 1/1 [==============================] - 0s 88ms/step
# 88.91907501220703 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 137 - 1
# 1/1 [==============================] - 0s 94ms/step
# 88.91898345947266 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 138 - 0
# 1/1 [==============================] - 0s 86ms/step
# 0.9374426007270813 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 139 - 0
# 1/1 [==============================] - 0s 79ms/step
# 0.9399975538253784 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 140 - 0
# 1/1 [==============================] - 0s 75ms/step
# 36.363826751708984 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 141 - 1
# 1/1 [==============================] - 0s 60ms/step
# 96.26643371582031 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 142 - 1
# 1/1 [==============================] - 0s 87ms/step
# 96.26643371582031 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 143 - 1
# 1/1 [==============================] - 0s 83ms/step
# 86.57331848144531 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 144 - 1
# 1/1 [==============================] - 0s 91ms/step
# 81.40445709228516 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 145 - 1
# 1/1 [==============================] - 0s 77ms/step
# 74.95608520507812 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 146 - 1
# 1/1 [==============================] - 0s 85ms/step
# 50.508445739746094 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 147 - 1
# 1/1 [==============================] - 0s 104ms/step
# 85.86302185058594 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 148 - 1
# 1/1 [==============================] - 0s 93ms/step
# 78.46027374267578 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 149 - 1
# 1/1 [==============================] - 0s 89ms/step
# 34.757652282714844 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 150 - 1
# 1/1 [==============================] - 0s 78ms/step
# 85.54401397705078 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 151 - 1
# 1/1 [==============================] - 0s 95ms/step
# 93.09884643554688 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 152 - 1
# 1/1 [==============================] - 0s 92ms/step
# 83.98103332519531 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 153 - 0
# 1/1 [==============================] - 0s 169ms/step
# 50.87177658081055 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 154 - 0
# 1/1 [==============================] - 0s 120ms/step
# 95.82608032226562 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 155 - 1
# 1/1 [==============================] - 0s 93ms/step
# 82.62883758544922 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 156 - 1
# 1/1 [==============================] - 0s 96ms/step
# 55.094764709472656 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 157 - 1
# 1/1 [==============================] - 0s 119ms/step
# 91.71394348144531 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 158 - 1
# 1/1 [==============================] - 0s 88ms/step
# 91.81375885009766 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 159 - 1
# 1/1 [==============================] - 0s 85ms/step
# 80.95721435546875 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 160 - 1
# 1/1 [==============================] - 0s 85ms/step
# 54.798526763916016 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 161 - 1
# 1/1 [==============================] - 0s 87ms/step
# 8.781469345092773 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 162 - 1
# 1/1 [==============================] - 0s 101ms/step
# 31.987751007080078 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 163 - 1
# 1/1 [==============================] - 0s 82ms/step
# 90.0521240234375 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 164 - 1
# 1/1 [==============================] - 0s 112ms/step
# 45.4537239074707 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 165 - 1
# 1/1 [==============================] - 0s 89ms/step
# 10.874424934387207 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 166 - 1
# 1/1 [==============================] - 0s 80ms/step
# 88.95336151123047 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 167 - 1
# 1/1 [==============================] - 0s 64ms/step
# 80.33805084228516 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 168 - 1
# 1/1 [==============================] - 0s 83ms/step
# 91.66323852539062 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 169 - 1
# 1/1 [==============================] - 0s 71ms/step
# 31.525480270385742 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 170 - 1
# 1/1 [==============================] - 0s 76ms/step
# 91.82757568359375 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 171 - 1
# 1/1 [==============================] - 0s 85ms/step
# 0.5660015344619751 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 172 - 1
# 1/1 [==============================] - 0s 85ms/step
# 54.834346771240234 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 173 - 1
# 1/1 [==============================] - 0s 80ms/step
# 76.53211975097656 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 174 - 1
# 1/1 [==============================] - 0s 89ms/step
# 55.2808952331543 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 175 - 1
# 1/1 [==============================] - 0s 79ms/step
# 15.558815002441406 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 176 - 1
# 1/1 [==============================] - 0s 83ms/step
# 8.809977531433105 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 177 - 1
# 1/1 [==============================] - 0s 114ms/step
# 91.82429504394531 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 178 - 1
# 1/1 [==============================] - 0s 101ms/step
# 55.231075286865234 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 179 - 1
# 1/1 [==============================] - 0s 72ms/step
# 55.00905990600586 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 180 - 1
# 1/1 [==============================] - 0s 77ms/step
# 98.05097961425781 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 181 - 0
# 1/1 [==============================] - 0s 85ms/step
# 22.151412963867188 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 182 - 0
# 1/1 [==============================] - 0s 69ms/step
# 55.16745376586914 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 183 - 0
# 1/1 [==============================] - 0s 75ms/step
# 91.81849670410156 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 184 - 0
# 1/1 [==============================] - 0s 86ms/step
# 53.5252685546875 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 185 - 0
# 1/1 [==============================] - 0s 122ms/step
# 55.341156005859375 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 186 - 0
# 1/1 [==============================] - 0s 86ms/step
# 30.899202346801758 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 187 - 0
# 1/1 [==============================] - 0s 73ms/step
# 0.4613419473171234 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 188 - 0
# 1/1 [==============================] - 0s 73ms/step
# 95.00208282470703 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 189 - 0
# 1/1 [==============================] - 0s 86ms/step
# 73.27705383300781 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 190 - 0
# 1/1 [==============================] - 0s 74ms/step
# 55.20610046386719 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 191 - 0
# 1/1 [==============================] - 0s 78ms/step
# 11.034198760986328 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 192 - 0
# 1/1 [==============================] - 0s 119ms/step
# 57.46744918823242 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 193 - 0
# 1/1 [==============================] - 0s 86ms/step
# 53.23112106323242 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 194 - 0
# 1/1 [==============================] - 0s 92ms/step
# 71.49890899658203 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 195 - 0
# 1/1 [==============================] - 0s 101ms/step
# 22.122051239013672 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 196 - 0
# 1/1 [==============================] - 0s 98ms/step
# 20.1181583404541 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 197 - 0
# 1/1 [==============================] - 0s 85ms/step
# 82.80918884277344 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 198 - 0
# 1/1 [==============================] - 0s 77ms/step
# 55.18836212158203 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 199 - 0
# 1/1 [==============================] - 0s 82ms/step
# 55.2628173828125 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 200 - 0
# 1/1 [==============================] - 0s 74ms/step
# 10.979592323303223 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 201 - 0
# 1/1 [==============================] - 0s 79ms/step
# 63.54308319091797 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 202 - 0
# 1/1 [==============================] - 0s 79ms/step
# 54.970211029052734 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 203 - 0
# 1/1 [==============================] - 0s 84ms/step
# 26.630386352539062 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 204 - 0
# 1/1 [==============================] - 0s 69ms/step
# 55.28654479980469 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
# 205 - 0
# 1/1 [==============================] - 0s 87ms/step
# 0.3752248287200928 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 206 - 0
# 1/1 [==============================] - 0s 75ms/step
# 13.321812629699707 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 207 - 0
# 1/1 [==============================] - 0s 66ms/step
# 0.3695780634880066 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 208 - 0
# 1/1 [==============================] - 0s 93ms/step
# 0.39353322982788086 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 209 - 0
# 1/1 [==============================] - 0s 114ms/step
# 0.37712353467941284 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 210 - 0
# 1/1 [==============================] - 0s 86ms/step
# 0.3779851496219635 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 211 - 0
# 1/1 [==============================] - 0s 85ms/step
# 0.37709128856658936 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 212 - 0
# 1/1 [==============================] - 0s 82ms/step
# 17.773109436035156 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 213 - 0
# 1/1 [==============================] - 0s 70ms/step
# 0.3810734152793884 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 214 - 0
# 1/1 [==============================] - 0s 82ms/step
# 0.37943512201309204 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 215 - 0
# 1/1 [==============================] - 0s 91ms/step
# 0.3794515132904053 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 216 - 0
# 1/1 [==============================] - 0s 112ms/step
# 0.382459819316864 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 217 - 0
# 1/1 [==============================] - 0s 79ms/step
# 0.3769938349723816 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 218 - 0
# 1/1 [==============================] - 0s 62ms/step
# 0.9277510643005371 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 219 - 0
# 1/1 [==============================] - 0s 71ms/step
# 0.37905392050743103 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 220 - 0
# 1/1 [==============================] - 0s 71ms/step
# 0.37718817591667175 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 221 - 0
# 1/1 [==============================] - 0s 69ms/step
# 0.9955495595932007 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 222 - 1
# 1/1 [==============================] - 0s 57ms/step
# 45.24601745605469 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 223 - 0
# 1/1 [==============================] - 0s 74ms/step
# 13.444164276123047 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 224 - 0
# 1/1 [==============================] - 0s 86ms/step
# 2.8114213943481445 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 225 - 0
# 1/1 [==============================] - 0s 78ms/step
# 1.8110398054122925 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 226 - 0
# 1/1 [==============================] - 0s 80ms/step
# 1.8110398054122925 % at 0 as 0(Normal)/1(Critcal)
# ======================================================================================
# 227 - 1
# 1/1 [==============================] - 0s 74ms/step
# 91.8094253540039 % at 1 as 0(Normal)/1(Critcal)
# ======================================================================================
#       id _predict_severity  severity
# 0      1                 1         1
# 1      2                 1         1
# 2      3                 1         0
# 3      4                 0         0
# 4      5                 1         1
# ..   ...               ...       ...
# 222  223                 0         0
# 223  224                 0         0
# 224  225                 0         0
# 225  226                 0         0
# 226  227                 1         1
#
# [227 rows x 3 columns]

# %% [markdown]
# # Classification Rerport

# %%
from sklearn.metrics import confusion_matrix,classification_report
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
className=list(set().union(list(dfPredictData['severity'].unique()),list(dfPredictData['_predict_severity'].unique())))
# className.sort(reverse=True)

# %%
actualClass=[  f'actual-{x}' for x in  className]
predictedlClass=[  f'predcited-{x}' for x in className]

y_true=list(dfPredictData['severity'])
y_pred=list(dfPredictData['_predict_severity'])
cnf_matrix = confusion_matrix(y_true,y_pred)
cnf_matrix

# #index=actual , column=prediction
cm_df = pd.DataFrame(cnf_matrix,
                     index = actualClass, 
                     columns = predictedlClass)
cm_df
# Out:
#           predcited-0  predcited-1
# actual-0           74           33
# actual-1           22           98

# %%
print(classification_report(y_true, y_pred, labels=className))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.69      0.73       107
#            1       0.75      0.82      0.78       120
#
#     accuracy                           0.76       227
#    macro avg       0.76      0.75      0.75       227
# weighted avg       0.76      0.76      0.76       227
